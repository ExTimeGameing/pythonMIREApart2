# %% [markdown]
# <a href="https://colab.research.google.com/github/ExTimeGameing/pythonMIREApart2/blob/master/%D0%91%D1%83%D0%B3%D1%80%D0%BE%D0%B2%D0%95%D0%B3%D0%BE%D1%80%D0%98%D0%BD%D0%B1%D0%BE_01_20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F%D0%A0%D0%B0%D0%B1%D0%BE%D1%82%D0%B02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Блок установок
# !pip install matplotlib
# !pip install ploty
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement ploty (from versions: none)
# ERROR: No matching distribution found for ploty

# %%
# @title Блок импортов
import matplotlib as mpl
import matplotlib.pyplot as plt
import ploty.graph_objs as go
import ploty.express as px
import numpy as np
import pandas as pd

# Путь до датасета
# %matplotlib notebook
dataset = '/content/supervillain_data_3.csv'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-dec230ffdb3f> in <cell line: 4>()
#       2 import matplotlib as mpl
#       3 import matplotlib.pyplot as plt
# ----> 4 import ploty.graph_objs as go
#       5 import ploty.express as px
#       6 import numpy as np
#
# ModuleNotFoundError: No module named 'ploty'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# @title Задание 1 "Найти и выгрузить многомернные данные pandas"

data = pd.read_csv(dataset, sep=",")

# %%
# @title Задание 2 "Вывод информации о данных"

data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               100 non-null    object
#  1   IGN_Rank           100 non-null    int64
#  2   Main_Ft_Apperance  96 non-null     object
#  3   No_Feature_Films   100 non-null    int64
#  4   Rating             96 non-null     float64
#  5   Award_Wins         96 non-null     float64
#  6   Nominations        96 non-null     float64
#  7   Gender             100 non-null    object
#  8   Human/Other        100 non-null    object
#  9   Type               100 non-null    object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 7.9+ KB
#             Name  IGN_Rank                 Main_Ft_Apperance  \
# 0          MADOK       100  Ant-Man and the Wasp:Quantumania
# 1  Fin Fang Foom        99           The invincible iron man
# ...

# %%
# @title Задание 3 "Построить стобчатую диаграмму"

# %%
# @title Задание 4

# %%
# @title Задание 5

# %%
# @title Задание 6

# %%
# @title Задание 7

# %%
# @title Задание 8
